# %%
import pandas as pd

# %%
df = pd.read_csv("Book1.csv")

# %%
df
# Out:
#                                                  name
# 0                             217. Contains Duplicate
# 1                                53. Maximum Subarray
# 2                                          1. Two Sum
# 3                              88. Merge Sorted Array
# 4                  350. Intersection of Two Arrays II
# 5                121. Best Time to Buy and Sell Stock
# 6                             566. Reshape the Matrix
# 7                              118. Pascal's Triangle
# 8                                    36. Valid Sudoku
# 9                              74. Search a 2D Matrix
# 10            387. First Unique Character in a String
# 11                                   383. Ransom Note
# 12                                 242. Valid Anagram
# 13                             141. Linked List Cycle
# 14                         21. Merge Two Sorted Lists
# 15                   203. Remove Linked List Elements
# 16                           206. Reverse Linked List
# 17             83. Remove Duplicates from Sorted List
# 18                              20. Valid Parentheses
# 19                  232. Implement Queue using Stacks
# 20                144. Binary Tree Preorder Traversal
# 21                  94. Binary Tree Inorder Traversal
# 22               145. Binary Tree Postorder Traversal
# 23             102. Binary Tree Level Order Traversal
# 24                  104. Maximum Depth of Binary Tree
# 25                                101. Symmetric Tree
# 26                            226. Invert Binary Tree
# 27                                      112. Path Sum
# 28                700. Search in a Binary Search Tree
# 29              701. Insert into a Binary Search Tree
# 30                    98. Validate Binary Search Tree
# 31                   653. Two Sum IV - Input is a BST
# 32  235. Lowest Common Ancestor of a Binary Search...

# %%
link = "https://leetcode.com/problems/"

# %%
leetcode_links = []

# %%
for i in df["name"]:
    k = ("-").join(i.split()[1:]).lower()
    print(k)
    leet_link = link + k
    print(leet_link)
    leetcode_links.append(leet_link)
# Out:
# maximum-size-subarray-sum-equals-k
# https://leetcode.com/problems/maximum-size-subarray-sum-equals-k
# minimum-swaps-to-group-all-1's-together
# https://leetcode.com/problems/minimum-swaps-to-group-all-1's-together
# sum-of-all-odd-length-subarrays
# https://leetcode.com/problems/sum-of-all-odd-length-subarrays
# minimum-number-of-arrows-to-burst-balloons
# https://leetcode.com/problems/minimum-number-of-arrows-to-burst-balloons
# longest-consecutive-sequence
# https://leetcode.com/problems/longest-consecutive-sequence
# 4sum-ii
# https://leetcode.com/problems/4sum-ii
# find-all-numbers-disappeared-in-an-array
# https://leetcode.com/problems/find-all-numbers-disappeared-in-an-array
# perform-string-shifts
# https://leetcode.com/problems/perform-string-shifts
# longest-palindrome
# https://leetcode.com/problems/longest-palindrome
# repeated-dna-sequences
# https://leetcode.com/problems/repeated-dna-sequences
# longest-palindromic-substring
# https://leetcode.com/problems/longest-palindromic-substring
# wildcard-matching
# https://leetcode.com/problems/wildcard-matching
# shortest-palindrome
# https://leetcode.com/problems/shortest-palindrome
# add-two-polynomials-represented-as-linked-lists
# https://leetcode.com/problems/add-two-polynomials-represented-as-linked-lists
# plus-one-linked-list
# https://leetcode.com/problems/plus-one-linked-list
# sort-list
# https://leetcode.com/problems/sort-list
# copy-list-with-random-pointer
# https://leetcode.com/problems/copy-list-with-random-pointer
# flatten-a-multilevel-doubly-linked-list
# https://leetcode.com/problems/flatten-a-multilevel-doubly-linked-list
# zigzag-iterator
# https://leetcode.com/problems/zigzag-iterator
# decode-string
# https://leetcode.com/problems/decode-string
# daily-temperatures
# https://leetcode.com/problems/daily-temperatures
# trapping-rain-water
# https://leetcode.com/problems/trapping-rain-water
# remove-k-digits
# https://leetcode.com/problems/remove-k-digits
# 132-pattern
# https://leetcode.com/problems/132-pattern
# largest-rectangle-in-histogram
# https://leetcode.com/problems/largest-rectangle-in-histogram
# shortest-subarray-with-sum-at-least-k
# https://leetcode.com/problems/shortest-subarray-with-sum-at-least-k
# find-nearest-right-node-in-binary-tree
# https://leetcode.com/problems/find-nearest-right-node-in-binary-tree
# find-all-the-lonely-nodes
# https://leetcode.com/problems/find-all-the-lonely-nodes
# diameter-of-n-ary-tree
# https://leetcode.com/problems/diameter-of-n-ary-tree
# house-robber-iii
# https://leetcode.com/problems/house-robber-iii
# delete-leaves-with-a-given-value
# https://leetcode.com/problems/delete-leaves-with-a-given-value
# find-leaves-of-binary-tree
# https://leetcode.com/problems/find-leaves-of-binary-tree
# binary-tree-maximum-path-sum
# https://leetcode.com/problems/binary-tree-maximum-path-sum
# binary-tree-cameras
# https://leetcode.com/problems/binary-tree-cameras
# possible-bipartition
# https://leetcode.com/problems/possible-bipartition
# cheapest-flights-within-k-stops
# https://leetcode.com/problems/cheapest-flights-within-k-stops
# graph-valid-tree
# https://leetcode.com/problems/graph-valid-tree
# number-of-provinces
# https://leetcode.com/problems/number-of-provinces
# satisfiability-of-equality-equations
# https://leetcode.com/problems/satisfiability-of-equality-equations
# number-of-operations-to-make-network-connected
# https://leetcode.com/problems/number-of-operations-to-make-network-connected
# number-of-islands-ii
# https://leetcode.com/problems/number-of-islands-ii
# remove-max-number-of-edges-to-keep-graph-fully-traversable
# https://leetcode.com/problems/remove-max-number-of-edges-to-keep-graph-fully-traversable
# number-of-connected-components-in-an-undirected-graph
# https://leetcode.com/problems/number-of-connected-components-in-an-undirected-graph
# the-earliest-moment-when-everyone-become-friends
# https://leetcode.com/problems/the-earliest-moment-when-everyone-become-friends
# meeting-rooms-ii
# https://leetcode.com/problems/meeting-rooms-ii
# merge-k-sorted-lists
# https://leetcode.com/problems/merge-k-sorted-lists
# kth-smallest-element-in-a-sorted-matrix
# https://leetcode.com/problems/kth-smallest-element-in-a-sorted-matrix
# find-median-from-data-stream
# https://leetcode.com/problems/find-median-from-data-stream
# rearrange-string-k-distance-apart
# https://leetcode.com/problems/rearrange-string-k-distance-apart
# employee-free-time
# https://leetcode.com/problems/employee-free-time
# the-skyline-problem
# https://leetcode.com/problems/the-skyline-problem
# design-most-recently-used-queue
# https://leetcode.com/problems/design-most-recently-used-queue
# my-calendar-i
# https://leetcode.com/problems/my-calendar-i
# find-servers-that-handled-most-number-of-requests
# https://leetcode.com/problems/find-servers-that-handled-most-number-of-requests
# implement-trie-(prefix-tree)
# https://leetcode.com/problems/implement-trie-(prefix-tree)
# design-add-and-search-words-data-structure
# https://leetcode.com/problems/design-add-and-search-words-data-structure
# longest-word-with-all-prefixes
# https://leetcode.com/problems/longest-word-with-all-prefixes
# word-search-ii
# https://leetcode.com/problems/word-search-ii
# palindrome-pairs
# https://leetcode.com/problems/palindrome-pairs
# design-search-autocomplete-system
# https://leetcode.com/problems/design-search-autocomplete-system

# %%
df["leetcode links"] = leetcode_links

# %%
df
# Out:
#                                                  name  \
# 0             325. Maximum Size Subarray Sum Equals k
# 1       1151. Minimum Swaps to Group All 1's Together
# 2               1588. Sum of All Odd Length Subarrays
# 3     452. Minimum Number of Arrows to Burst Balloons
# 4                   128. Longest Consecutive Sequence
# 5                                        454. 4Sum II
# 6       448. Find All Numbers Disappeared in an Array
# 7                         1427. Perform String Shifts
# 8                             409. Longest Palindrome
# 9                         187. Repeated DNA Sequences
# 10                   5. Longest Palindromic Substring
# 11                              44. Wildcard Matching
# 12                           214. Shortest Palindrome
# 13  1634. Add Two Polynomials Represented as Linke...
# 14                          369. Plus One Linked List
# 15                                     148. Sort List
# 16                 138. Copy List with Random Pointer
# 17       430. Flatten a Multilevel Doubly Linked List
# 18                               281. Zigzag Iterator
# 19                                 394. Decode String
# 20                            739. Daily Temperatures
# 21                            42. Trapping Rain Water
# 22                               402. Remove K Digits
# 23                                   456. 132 Pattern
# 24                 84. Largest Rectangle in Histogram
# 25         862. Shortest Subarray with Sum at Least K
# 26       1602. Find Nearest Right Node in Binary Tree
# 27                    1469. Find All The Lonely Nodes
# 28                       1522. Diameter of N-Ary Tree
# 29                              337. House Robber III
# 30             1325. Delete Leaves With a Given Value
# 31                    366. Find Leaves of Binary Tree
# 32                  124. Binary Tree Maximum Path Sum
# 33                           968. Binary Tree Cameras
# 34                          886. Possible Bipartition
# 35               787. Cheapest Flights Within K Stops
# 36                              261. Graph Valid Tree
# 37                           547. Number of Provinces
# 38          990. Satisfiability of Equality Equations
# 39  1319. Number of Operations to Make Network Con...
# 40                          305. Number of Islands II
# 41  1579. Remove Max Number of Edges to Keep Graph...
# 42  323. Number of Connected Components in an Undi...
# 43  1101. The Earliest Moment When Everyone Become...
# 44                              253. Meeting Rooms II
# 45                           23. Merge k Sorted Lists
# 46       378. Kth Smallest Element in a Sorted Matrix
# 47                  295. Find Median from Data Stream
# 48             358. Rearrange String k Distance Apart
# 49                            759. Employee Free Time
# 50                           218. The Skyline Problem
# 51              1756. Design Most Recently Used Queue
# 52                                 729. My Calendar I
# 53  1606. Find Servers That Handled Most Number of...
# 54                  208. Implement Trie (Prefix Tree)
# 55    211. Design Add and Search Words Data Structure
# 56               1858. Longest Word With All Prefixes
# 57                                212. Word Search II
# 58                              336. Palindrome Pairs
# 59             642. Design Search Autocomplete System
#
#                                        leetcode links
# 0   https://leetcode.com/problems/maximum-size-sub...
# 1   https://leetcode.com/problems/minimum-swaps-to...
# 2   https://leetcode.com/problems/sum-of-all-odd-l...
# 3   https://leetcode.com/problems/minimum-number-o...
# 4   https://leetcode.com/problems/longest-consecut...
# 5               https://leetcode.com/problems/4sum-ii
# 6   https://leetcode.com/problems/find-all-numbers...
# 7   https://leetcode.com/problems/perform-string-s...
# 8    https://leetcode.com/problems/longest-palindrome
# 9   https://leetcode.com/problems/repeated-dna-seq...
# 10  https://leetcode.com/problems/longest-palindro...
# 11    https://leetcode.com/problems/wildcard-matching
# 12  https://leetcode.com/problems/shortest-palindrome
# 13  https://leetcode.com/problems/add-two-polynomi...
# 14  https://leetcode.com/problems/plus-one-linked-...
# 15            https://leetcode.com/problems/sort-list
# 16  https://leetcode.com/problems/copy-list-with-r...
# 17  https://leetcode.com/problems/flatten-a-multil...
# 18      https://leetcode.com/problems/zigzag-iterator
# 19        https://leetcode.com/problems/decode-string
# 20   https://leetcode.com/problems/daily-temperatures
# 21  https://leetcode.com/problems/trapping-rain-water
# 22      https://leetcode.com/problems/remove-k-digits
# 23          https://leetcode.com/problems/132-pattern
# 24  https://leetcode.com/problems/largest-rectangl...
# 25  https://leetcode.com/problems/shortest-subarra...
# 26  https://leetcode.com/problems/find-nearest-rig...
# 27  https://leetcode.com/problems/find-all-the-lon...
# 28  https://leetcode.com/problems/diameter-of-n-ar...
# 29     https://leetcode.com/problems/house-robber-iii
# 30  https://leetcode.com/problems/delete-leaves-wi...
# 31  https://leetcode.com/problems/find-leaves-of-b...
# 32  https://leetcode.com/problems/binary-tree-maxi...
# 33  https://leetcode.com/problems/binary-tree-cameras
# 34  https://leetcode.com/problems/possible-biparti...
# 35  https://leetcode.com/problems/cheapest-flights...
# 36     https://leetcode.com/problems/graph-valid-tree
# 37  https://leetcode.com/problems/number-of-provinces
# 38  https://leetcode.com/problems/satisfiability-o...
# 39  https://leetcode.com/problems/number-of-operat...
# 40  https://leetcode.com/problems/number-of-island...
# 41  https://leetcode.com/problems/remove-max-numbe...
# 42  https://leetcode.com/problems/number-of-connec...
# 43  https://leetcode.com/problems/the-earliest-mom...
# 44     https://leetcode.com/problems/meeting-rooms-ii
# 45  https://leetcode.com/problems/merge-k-sorted-l...
# 46  https://leetcode.com/problems/kth-smallest-ele...
# 47  https://leetcode.com/problems/find-median-from...
# 48  https://leetcode.com/problems/rearrange-string...
# 49   https://leetcode.com/problems/employee-free-time
# 50  https://leetcode.com/problems/the-skyline-problem
# 51  https://leetcode.com/problems/design-most-rece...
# 52        https://leetcode.com/problems/my-calendar-i
# 53  https://leetcode.com/problems/find-servers-tha...
# 54  https://leetcode.com/problems/implement-trie-(...
# 55  https://leetcode.com/problems/design-add-and-s...
# 56  https://leetcode.com/problems/longest-word-wit...
# 57       https://leetcode.com/problems/word-search-ii
# 58     https://leetcode.com/problems/palindrome-pairs
# 59  https://leetcode.com/problems/design-search-au...

# %%
df.to_csv("Book1_updated.csv", index=False)

# %% [markdown]
# ## create markdown

# %%
df
# Out:
#                                                  name
# 0                             217. Contains Duplicate
# 1                                53. Maximum Subarray
# 2                                          1. Two Sum
# 3                              88. Merge Sorted Array
# 4                  350. Intersection of Two Arrays II
# 5                121. Best Time to Buy and Sell Stock
# 6                             566. Reshape the Matrix
# 7                              118. Pascal's Triangle
# 8                                    36. Valid Sudoku
# 9                              74. Search a 2D Matrix
# 10            387. First Unique Character in a String
# 11                                   383. Ransom Note
# 12                                 242. Valid Anagram
# 13                             141. Linked List Cycle
# 14                         21. Merge Two Sorted Lists
# 15                   203. Remove Linked List Elements
# 16                           206. Reverse Linked List
# 17             83. Remove Duplicates from Sorted List
# 18                              20. Valid Parentheses
# 19                  232. Implement Queue using Stacks
# 20                144. Binary Tree Preorder Traversal
# 21                  94. Binary Tree Inorder Traversal
# 22               145. Binary Tree Postorder Traversal
# 23             102. Binary Tree Level Order Traversal
# 24                  104. Maximum Depth of Binary Tree
# 25                                101. Symmetric Tree
# 26                            226. Invert Binary Tree
# 27                                      112. Path Sum
# 28                700. Search in a Binary Search Tree
# 29              701. Insert into a Binary Search Tree
# 30                    98. Validate Binary Search Tree
# 31                   653. Two Sum IV - Input is a BST
# 32  235. Lowest Common Ancestor of a Binary Search...

# %%
for i in df["name"]:
    k = i.split(" ")
    num_str = "".join([k[0],k[1]])
    print(" ".join())
    print(f"- [ ] {i}")
# Out:
# 217.Contains
# - [ ] 217. Contains Duplicate
# 53.Maximum
# - [ ] 53. Maximum Subarray
# 1.Two
# - [ ] 1. Two Sum
# 88.Merge
# - [ ] 88. Merge Sorted Array
# 350.Intersection
# - [ ] 350. Intersection of Two Arrays II
# 121.Best
# - [ ] 121. Best Time to Buy and Sell Stock
# 566.Reshape
# - [ ] 566. Reshape the Matrix
# 118.Pascal's
# - [ ] 118. Pascal's Triangle
# 36.Valid
# - [ ] 36. Valid Sudoku
# 74.Search
# - [ ] 74. Search a 2D Matrix
# 387.First
# - [ ] 387. First Unique Character in a String
# 383.Ransom
# - [ ] 383. Ransom Note
# 242.Valid
# - [ ] 242. Valid Anagram
# 141.Linked
# - [ ] 141. Linked List Cycle
# 21.Merge
# - [ ] 21. Merge Two Sorted Lists
# 203.Remove
# - [ ] 203. Remove Linked List Elements
# 206.Reverse
# - [ ] 206. Reverse Linked List
# 83.Remove
# - [ ] 83. Remove Duplicates from Sorted List
# 20.Valid
# - [ ] 20. Valid Parentheses
# 232.Implement
# - [ ] 232. Implement Queue using Stacks
# 144.Binary
# - [ ] 144. Binary Tree Preorder Traversal
# 94.Binary
# - [ ] 94. Binary Tree Inorder Traversal
# 145.Binary
# - [ ] 145. Binary Tree Postorder Traversal
# 102.Binary
# - [ ] 102. Binary Tree Level Order Traversal
# 104.Maximum
# - [ ] 104. Maximum Depth of Binary Tree
# 101.Symmetric
# - [ ] 101. Symmetric Tree
# 226.Invert
# - [ ] 226. Invert Binary Tree
# 112.Path
# - [ ] 112. Path Sum
# 700.Search
# - [ ] 700. Search in a Binary Search Tree
# 701.Insert
# - [ ] 701. Insert into a Binary Search Tree
# 98.Validate
# - [ ] 98. Validate Binary Search Tree
# 653.Two
# - [ ] 653. Two Sum IV - Input is a BST
# 235.Lowest
# - [ ] 235. Lowest Common Ancestor of a Binary Search Tree
